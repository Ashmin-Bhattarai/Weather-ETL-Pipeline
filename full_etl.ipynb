# %%
# %fs rm -r /user/hive/warehouse/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res0: Boolean = true
# </div>

# %%
# %sql
drop table if exists weather_log_table;
drop table if exists raw_weather;
drop table if exists processed_weather;
drop table if exists hourly_fact_weather;
drop table if exists daily_fact_weather;
drop table if exists dim_city;
drop table if exists dim_date;
drop table if exists dim_time;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %pip install python-dotenv
# Out:
# Python interpreter will be restarted.
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Python interpreter will be restarted.

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/log_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/date_time_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/city_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/raw_weather_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/processed_weather_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/fact_weather_utils"

# %% [markdown]
# ## Main Pipeline

# %%
create_log_table()
load_date()
load_time()
load_cities()
# Out:
# /databricks/spark/python/pyspark/pandas/namespace.py:1881: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   pd.date_range(

# %%
# import time

# while True:
df_raw = get_raw_weather('RAW', 'raw_weather')
print("\n==========================Raw Extraction Completed==========================\n")
df_processed = get_process_weather('PROCESSED', 'processed_weather', df_raw)
print("\n==========================Processes Extraction Completed==========================\n")
df_fact_hourly = get_hourly_fact_weather('FACT', 'hourly_fact_weather', df_processed)
print("\n==========================Fact Hourly Extraction Completed==========================\n")
df_fact_daily = get_daily_fact_weather('FACT', 'daily_fact_weather', df_processed)
print("\n==========================Fact Daily Extraction Completed==========================\n")
    
#     time.sleep(30*60)
# Out:
# ==========================Raw Extraction Completed==========================
#
#
# ==========================Processes Extraction Completed==========================
#
#
# ==========================Fact Hourly Extraction Completed==========================
#
#
# ==========================Fact Daily Extraction Completed==========================

# %%
# %sql
select * from raw_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>List(10000, 20700, List(310.48, 308.28, 310.48, 310.48, 1004, 16, 1004, 922), List(null), List(NP, 1686180491, 1686230388), 1686198605, List(83.7667, 27.9833), Wāliṅ, List(List(800, Clear, clear sky, 01d)), 200, 1282616, List(null, 143, 3.7), stations)</td><td>6e71abc7-6f0a-441e-b8de-4b860b08e4e0</td><td>2023-06-08T04:38:42.302+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(308.99, 306.67, 308.99, 308.99, 1003, 16, 1003, 892), List(null), List(NP, 1686180329, 1686230167), 1686198605, List(84.5667, 27.7667), Upardang Gadhi, List(List(800, Clear, clear sky, 01d)), 200, 1282621, List(null, 215, 3.92), stations)</td><td>6e71abc7-6f0a-441e-b8de-4b860b08e4e0</td><td>2023-06-08T04:38:42.302+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(310.28, 308.2, 310.28, 310.28, 1004, 17, 1004, 933), List(null), List(NP, 1686180824, 1686230761), 1686198605, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01d)), 200, 1282635, List(null, 239, 5.38), stations)</td><td>6e71abc7-6f0a-441e-b8de-4b860b08e4e0</td><td>2023-06-08T04:38:42.302+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(314.69, 312.74, 314.69, 314.69, 1002, 14, 1002, 981), List(null), List(NP, 1686180363, 1686230165), 1686198606, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null, 204, 4.21), stations)</td><td>6e71abc7-6f0a-441e-b8de-4b860b08e4e0</td><td>2023-06-08T04:38:42.302+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(313.91, 311.56, 313.91, 313.91, 1002, 13, 1002, 985), List(null), List(NP, 1686181053, 1686231091), 1686198606, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01d)), 200, 1282666, List(null, 255, 2.29), stations)</td><td>6e71abc7-6f0a-441e-b8de-4b860b08e4e0</td><td>2023-06-08T04:38:42.302+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(310.48, 308.28, 310.48, 310.48, 1004, 16, 1004, 922), List(null), List(NP, 1686180491, 1686230388), 1686198607, List(83.7667, 27.9833), Wāliṅ, List(List(800, Clear, clear sky, 01d)), 200, 1282616, List(null, 143, 3.7), stations)</td><td>63a50d17-8a32-4c66-bc52-09c7bb2146f9</td><td>2023-06-08T04:29:58.780+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(308.99, 306.67, 308.99, 308.99, 1003, 16, 1003, 892), List(null), List(NP, 1686180329, 1686230167), 1686198611, List(84.5667, 27.7667), Upardang Gadhi, List(List(800, Clear, clear sky, 01d)), 200, 1282621, List(null, 215, 3.92), stations)</td><td>63a50d17-8a32-4c66-bc52-09c7bb2146f9</td><td>2023-06-08T04:29:58.780+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(310.28, 308.2, 310.28, 310.28, 1004, 17, 1004, 933), List(null), List(NP, 1686180824, 1686230761), 1686198612, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01d)), 200, 1282635, List(null, 239, 5.38), stations)</td><td>63a50d17-8a32-4c66-bc52-09c7bb2146f9</td><td>2023-06-08T04:29:58.780+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(314.69, 312.74, 314.69, 314.69, 1002, 14, 1002, 981), List(null), List(NP, 1686180363, 1686230165), 1686198609, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null,