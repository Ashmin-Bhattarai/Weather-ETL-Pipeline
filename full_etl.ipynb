# %%
# %fs rm -r /user/hive/warehouse/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res0: Boolean = true
# </div>

# %%
# %sql
drop table if exists weather_log_table;
drop table if exists raw_weather;
drop table if exists processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %pip install python-dotenv
# Out:
# Python interpreter will be restarted.
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Python interpreter will be restarted.

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/log_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/date_time_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/city_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/raw_weather_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/processed_weather_utils"

# %% [markdown]
# ## Main Pipeline

# %%
create_log_table()
load_date()
load_time()
load_cities()
# Out:
# /databricks/spark/python/pyspark/pandas/namespace.py:1881: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   pd.date_range(

# %%
df_raw = get_raw_weather('RAW', 'raw_weather')
df_processed = get_process_weather('PROCESSED', 'processed_weather', df_raw)

# %%
# %sql
select * from raw_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>List(10000, 20700, List(310.51, 308.31, 310.51, 310.51, 1004, 16, 1004, 921), List(null), List(NP, 1686094096, 1686143963), 1686117974, List(83.7667, 27.9833), Wāliṅ, List(List(800, Clear, clear sky, 01d)), 200, 1282616, List(null, 158, 2.33), stations)</td><td>7b6df759-6ced-4ec5-8bbd-a5cf968c64e0</td><td>2023-06-07T06:14:05.462+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(308.45, 306.3, 308.45, 308.45, 1003, 18, 1003, 892), List(null), List(NP, 1686093933, 1686143741), 1686117974, List(84.5667, 27.7667), Upardang Gadhi, List(List(800, Clear, clear sky, 01d)), 200, 1282621, List(null, 219, null), stations)</td><td>7b6df759-6ced-4ec5-8bbd-a5cf968c64e0</td><td>2023-06-07T06:14:05.462+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(309.79, 308.1, 309.79, 309.79, 1004, 20, 1004, 933), List(null), List(NP, 1686094429, 1686144335), 1686117974, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01d)), 200, 1282635, List(null, 214, 3.73), stations)</td><td>7b6df759-6ced-4ec5-8bbd-a5cf968c64e0</td><td>2023-06-07T06:14:05.462+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(314.34, 313.22, 314.34, 314.34, 1002, 17, 1002, 981), List(null), List(NP, 1686093967, 1686143739), 1686117975, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null, 211, 2.77), stations)</td><td>7b6df759-6ced-4ec5-8bbd-a5cf968c64e0</td><td>2023-06-07T06:14:05.462+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(314.25, 312.21, 314.25, 314.25, 1002, 14, 1002, 985), List(null), List(NP, 1686094658, 1686144665), 1686117975, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01d)), 200, 1282666, List(null, 268, 3.03), stations)</td><td>7b6df759-6ced-4ec5-8bbd-a5cf968c64e0</td><td>2023-06-07T06:14:05.462+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(310.51, 308.31, 310.51, 310.51, 1004, 16, 1004, 921), List(null), List(NP, 1686094096, 1686143963), 1686117980, List(83.7667, 27.9833), Wāliṅ, List(List(800, Clear, clear sky, 01d)), 200, 1282616, List(null, 158, 2.33), stations)</td><td>3bcb18ab-e876-478d-8755-edfd7a6b35a3</td><td>2023-06-07T06:06:09.879+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(308.45, 306.3, 308.45, 308.45, 1003, 18, 1003, 892), List(null), List(NP, 1686093933, 1686143741), 1686117974, List(84.5667, 27.7667), Upardang Gadhi, List(List(800, Clear, clear sky, 01d)), 200, 1282621, List(null, 219, null), stations)</td><td>3bcb18ab-e876-478d-8755-edfd7a6b35a3</td><td>2023-06-07T06:06:09.879+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(309.79, 308.1, 309.79, 309.79, 1004, 20, 1004, 933), List(null), List(NP, 1686094429, 1686144335), 1686117980, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01d)), 200, 1282635, List(null, 214, 3.73), stations)</td><td>3bcb18ab-e876-478d-8755-edfd7a6b35a3</td><td>2023-06-07T06:06:09.879+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(314.34, 313.22, 314.34, 314.34, 1002, 17, 1002, 981), List(null), List(NP, 1686093967, 1686143739), 1686117975, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null, 211, 2.77), stations)</td><td>3bcb18ab-e876-478d-8755-edfd7a6b35a3</td><td>2023-06-07T06:06:09.879+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(314.25, 312.21, 314.25, 314.25, 1002, 14, 1002, 985), List(null), List(NP, 1686094658, 1686144665), 1686117820, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01d)), 200, 1282666, List(null, 268, 3.03), stations)</td><td>3bcb18ab-e876-478d-8755-edfd7a6b35a3</td><td>2023-06-07T06:06:09.879+0000</td><td>Ashmin Bhattarai</td></tr> ...

# %%
# %sql
select * from processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dt</th><th>date</th><th>city_id</th><th>city_name</th><th>timezone</th><th>country</th><th>lat</th><th>lon</th><th>temp</th><th>temp_min</th><th>temp_max</th><th>pressure</th><th>humidity</th><th>visibility</th><th>wind_speed</th><th>wind_deg</th><th>wind_gust</th><th>clouds_all</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>1686117974</td><td>2023-06-07 06:06:14</td><td>1282616</td><td>Wāliṅ</td><td>20700</td><td>NP</td><td>27.9833</td><td>83.7667</td><td>310.51</td><td>310.51</td><td>310.51</td><td>1004</td><td>16</td><td>10000</td><td>null</td><td>158</td><td>2.33</td><td>null</td><td>8c155953-2a62-443a-b0e1-88a41fa83dcf</td><td>2023-06-07T06:14:22.291+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686117974</td><td>2023-06-07 06:06:14</td><td>1282621</td><td>Upardang Gadhi</td><td>20700</td><td>NP</td><td>27.7667</td><td>84.5667</td><td>308.45</td><td>308.45</td><td>308.45</td><td>1003</td><td>18</td><td>10000</td><td>null</td><td>219</td><td>null</td><td>null</td><td>8c155953-2a62-443a-b0e1-88a41fa83dcf</td><td>2023-06-07T06:14:22.291+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686117974</td><td>2023-06-07 06:06:14</td><td>1282635</td><td>Tulsīpur</td><td>20700</td><td>NP</td><td>28.131</td><td>82.2973</td><td