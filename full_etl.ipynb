# %%
# %fs rm -r /user/hive/warehouse/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res0: Boolean = true
# </div>

# %%
# %sql
drop table if exists weather_log_table;
drop table if exists raw_weather;
drop table if exists processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-6f7025b8-8b88-4a92-a713-3e040f5111be/bin/python -m pip install --upgrade pip' command.

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/log_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/date_time_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/city_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/raw_weather_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/processed_weather_utils"

# %% [markdown]
# ## Main Pipeline

# %%
create_log_table()
load_date()
load_time()
load_cities()
# Out:
# /databricks/spark/python/pyspark/pandas/namespace.py:1881: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   pd.date_range(

# %%
_ = get_raw_weather('RAW', 'raw_weather')

# %%
_ = get_process_weather('PROCESSED', 'processed_weather')

# %%
# %sql
select * from raw_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>List(10000, 20700, List(309.54, 307.65, 309.54, 309.54, 1005, 19, 1005, 922), List(null), List(NP, 1686094096, 1686143963), 1686115664, List(83.7667, 27.9833), Wāliṅ, List(List(800, Clear, clear sky, 01d)), 200, 1282616, List(null, 157, 2.2), stations)</td><td>5bdf27e6-9d8a-4504-a6e8-519832798b60</td><td>2023-06-07T05:27:32.632+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(307.78, 305.79, 307.78, 307.78, 1004, 20, 1004, 893), List(null), List(NP, 1686093933, 1686143741), 1686115664, List(84.5667, 27.7667), Upardang Gadhi, List(List(800, Clear, clear sky, 01d)), 200, 1282621, List(null, 224, 2.25), stations)</td><td>5bdf27e6-9d8a-4504-a6e8-519832798b60</td><td>2023-06-07T05:27:32.632+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(309.18, 307.53, 309.18, 309.18, 1005, 21, 1005, 934), List(null), List(NP, 1686094429, 1686144335), 1686115661, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01d)), 200, 1282635, List(null, 207, 3.9), stations)</td><td>5bdf27e6-9d8a-4504-a6e8-519832798b60</td><td>2023-06-07T05:27:32.632+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(313.73, 313.03, 313.73, 313.73, 1003, 19, 1003, 982), List(null), List(NP, 1686093967, 1686143739), 1686115665, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null, 211, 1.88), stations)</td><td>5bdf27e6-9d8a-4504-a6e8-519832798b60</td><td>2023-06-07T05:27:32.632+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(313.17, 311.43, 313.17, 313.17, 1003, 16, 1003, 986), List(null), List(NP, 1686094658, 1686144665), 1686115665, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01d)), 200, 1282666, List(null, 264, 2.88), stations)</td><td>5bdf27e6-9d8a-4504-a6e8-519832798b60</td><td>2023-06-07T05:27:32.632+0000</td><td>Ashmin Bhattarai</td></tr></tbody></table></div>

# %%
# %sql
select * from processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dt</th><th>date</th><th>city_id</th><th>city_name</th><th>timezone</th><th>country</th><th>lat</th><th>lon</th><th>temp</th><th>temp_min</th><th>temp_max</th><th>pressure</th><th>humidity</th><th>visibility</th><th>wind_speed</th><th>wind_deg</th><th>wind_gust</th><th>clouds_all</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>1686115664</td><td>2023-06-07 05:27:44</td><td>1282616</td><td>Wāliṅ</td><td>20700</td><td>NP</td><td>27.9833</td><td>83.7667</td><td>309.54</td><td>309.54</td><td>309.54</td><td>1005</td><td>19</td><td>10000</td><td>null</td><td>157</td><td>2.2</td><td>null</td><td>e8d63c67-9dc7-4f05-83df-abfc4dd7c21c</td><td>2023-06-07T05:27:53.738+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686115664</td><td>2023-06-07 05:27:44</td><td>1282621</td><td>Upardang Gadhi</td><td>20700</td><td>NP</td><td>27.7667</td><td>84.5667</td><td>307.78</td><td>307.78</td><td>307.78</td><td>1004</td><td>20</td><td>10000</td><td>null</td><td>224</td><td>2.25</td><td>null</td><td>e8d63c67-9dc7-4f05-83df-abfc4dd7c21c</td><td>2023-06-07T05:27:53.738+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686115661</td><td>2023-06-07 05:27:41</td><td>1282635</td><td>Tulsīpur</td><td>20700</td><td>NP</td><td>28.131</td><td>82.2973</td><td>309.18</td><td>309.18</td><td>309.18</td><td>1005</td><td>21</td><td>10000</td><td>null</td><td>207</td><td>3.9</td><td>null</td><td>e8d63c67-9dc7-4f05-83df-abfc4dd7c21c</td><td>2023-06-07T05:27:53.738+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686115665</td><td>2023-06-07 05:27:45</td><td>1282665</td><td>Tikoli</td><td>20700</td><td>NP</td><td>27.6333</td><td>84.5</td><td>313.73</td><td>313.73</td><td>313.73</td><td>1003</td><td>19</td><td>10000</td><td>null</td><td>211</td><td>1.88</td><td>null</td><td>e8d63c67-9dc7-4f05-83df-abfc4dd7c21c</td><td>2023-06-07T05:27:53.738+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686115665</td><td>2023-06-07 05:27:45</td><td>1282666</td><td>Ṭikāpur</td><td>20700</td><td>NP</td><td>28.5</td><td>81.1333</td><td>313.17</td><td>313.17</td><td>313.17</td><td>1003</td><td>16</td><td>10000</td><td>null</td><td>264</td><td>2.88</td><td>null</td><td>e8d63c67-9dc7-4f05-83df-abfc4dd7c21c</td><td>2023-06-07T05:27:53.738+0000</td><td>Ashmin Bhattarai</td></tr></tbody></table></div>

# %%
# %sql
select * from weather_log_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>load_type</th><th>table_name</th><th>process_start_time</th><th>process_end_time</th><th>status</th><th>comments</th><th>start_date_time</th><th>end_date_time</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>e8d63c67-9dc7-4f05-83df-abfc4dd7c21c</td><td>PROCESSED</td><td>processed_weather</td><td>2023-06-07T05:27:53.738+0000</td><td>2023-06-07T05:28:02.836+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-07T05:27:41.000+0000</td><td>2023-06-07T05:27:45.000+0000</td><td>2023-06-07T05:27:53.738+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>5bdf27e6-9d8a-4504-a6e8-519832798b60</td><td>RAW</td><td>raw_weather</td><td>2023-06-07T05:27:32.632+0000</td><td>2023-06-07T05:27:48.552+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-07T05:27:37.000+0000</td><td>2023-06-07T05:27:41.000+0000</td><td>2023-06-07T05:27:32.632+0000</td><td>Ashmin Bhattarai</td></tr></tbody></table></div>
