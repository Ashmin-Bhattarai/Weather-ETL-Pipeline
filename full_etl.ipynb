# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/log_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/date_time_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/city_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/raw_weather_utils"

# %%
# %run "/Users/koushalashmin@gmail.com/WeatherETL/utils/processed_weather_utils"

# %%
create_log_table()
load_date()
load_time()
load_cities()
get_raw_weather('RAW', 'raw_weather')
get_process_weather('PROCESSED', 'processed_weather')
# Out:
# /databricks/spark/python/pyspark/pandas/namespace.py:1881: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   pd.date_range(
# Out[8]: DataFrame[dt: int, date: string, city_id: int, city_name: string, timezone: int, country: string, lat: float, lon: float, temp: float, temp_min: float, temp_max: float, pressure: int, humidity: int, visibility: int, wind_speed: int, wind_deg: int, wind_gust: float, clouds_all: float, load_run_id: string, created_on: timestamp, created_by: string]

# %%
# %sql
select * from raw_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>List(10000, 20700, List(297.68, 297.26, 297.68, 297.68, 1006, 41, 1006, 920), List(null), List(NP, 1686094096, 1686143963), 1686077641, List(83.7667, 27.9833), Wāliṅ, List(List(802, Clouds, scattered clouds, 03n)), 200, 1282616, List(null, 348, 1.76), stations)</td><td>57cda229-09ce-42c4-8a77-3cb05af044ac</td><td>2023-06-06T18:57:47.633+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(295.15, 294.61, 295.15, 295.15, 1004, 46, 1004, 889), List(null), List(NP, 1686093933, 1686143741), 1686077641, List(84.5667, 27.7667), Upardang Gadhi, List(List(801, Clouds, few clouds, 02n)), 200, 1282621, List(null, 37, 2.71), stations)</td><td>57cda229-09ce-42c4-8a77-3cb05af044ac</td><td>2023-06-06T18:57:47.633+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(297.46, 297.07, 297.46, 297.46, 1006, 43, 1006, 932), List(null), List(NP, 1686094429, 1686144335), 1686077641, List(82.2973, 28.131), Tulsīpur, List(List(800, Clear, clear sky, 01n)), 200, 1282635, List(null, 25, 2.36), stations)</td><td>57cda229-09ce-42c4-8a77-3cb05af044ac</td><td>2023-06-06T18:57:47.633+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(300.69, 300.68, 300.69, 300.69, 1003, 44, 1003, 981), List(null), List(NP, 1686093967, 1686143739), 1686077639, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01n)), 200, 1282665, List(null, 47, 2.35), stations)</td><td>57cda229-09ce-42c4-8a77-3cb05af044ac</td><td>2023-06-06T18:57:47.633+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>List(10000, 20700, List(300.54, 300.42, 300.54, 300.54, 1003, 42, 1003, 985), List(null), List(NP, 1686094658, 1686144665), 1686077639, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01n)), 200, 1282666, List(null, 31, 4.57), stations)</td><td>57cda229-09ce-42c4-8a77-3cb05af044ac</td><td>2023-06-06T18:57:47.633+0000</td><td>Ashmin Bhattarai</td></tr></tbody></table></div>

# %%
# %sql
select * from processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dt</th><th>date</th><th>city_id</th><th>city_name</th><th>timezone</th><th>country</th><th>lat</th><th>lon</th><th>temp</th><th>temp_min</th><th>temp_max</th><th>pressure</th><th>humidity</th><th>visibility</th><th>wind_speed</th><th>wind_deg</th><th>wind_gust</th><th>clouds_all</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>1686077641</td><td>2023-06-06 18:54:01</td><td>1282616</td><td>Wāliṅ</td><td>20700</td><td>NP</td><td>27.9833</td><td>83.7667</td><td>297.68</td><td>297.68</td><td>297.68</td><td>1006</td><td>41</td><td>10000</td><td>null</td><td>348</td><td>1.76</td><td>null</td><td>3c2c2c93-0049-4d24-9572-daf1955e3cc6</td><td>2023-06-06T18:58:10.598+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686077641</td><td>2023-06-06 18:54:01</td><td>1282621</td><td>Upardang Gadhi</td><td>20700</td><td>NP</td><td>27.7667</td><td>84.5667</td><td>295.15</td><td>295.15</td><td>295.15</td><td>1004</td><td>46</td><td>10000</td><td>null</td><td>37</td><td>2.71</td><td>null</td><td>3c2c2c93-0049-4d24-9572-daf1955e3cc6</td><td>2023-06-06T18:58:10.598+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686077641</td><td>2023-06-06 18:54:01</td><td>1282635</td><td>Tulsīpur</td><td>20700</td><td>NP</td><td>28.131</td><td>82.2973</td><td>297.46</td><td>297.46</td><td>297.46</td><td>1006</td><td>43</td><td>10000</td><td>null</td><td>25</td><td>2.36</td><td>null</td><td>3c2c2c93-0049-4d24-9572-daf1955e3cc6</td><td>2023-06-06T18:58:10.598+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686077639</td><td>2023-06-06 18:53:59</td><td>1282665</td><td>Tikoli</td><td>20700</td><td>NP</td><td>27.6333</td><td>84.5</td><td>300.69</td><td>300.69</td><td>300.69</td><td>1003</td><td>44</td><td>10000</td><td>null</td><td>47</td><td>2.35</td><td>null</td><td>3c2c2c93-0049-4d24-9572-daf1955e3cc6</td><td>2023-06-06T18:58:10.598+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>1686077639</td><td>2023-06-06 18:53:59</td><td>1282666</td><td>Ṭikāpur</td><td>20700</td><td>NP</td><td>28.5</td><td>81.1333</td><td>300.54</td><td>300.54</td><td>300.54</td><td>1003</td><td>42</td><td>10000</td><td>null</td><td>31</td><td>4.57</td><td>null</td><td>3c2c2c93-0049-4d24-9572-daf1955e3cc6</td><td>2023-06-06T18:58:10.598+0000</td><td>Ashmin Bhattarai</td></tr></tbody></table></div>

# %%
# %sql
select * from weather_log_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>load_type</th><th>table_name</th><th>process_start_time</th><th>process_end_time</th><th>status</th><th>comments</th><th>start_date_time</th><th>end_date_time</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>3c2c2c93-0049-4d24-9572-daf1955e3cc6</td><td>PROCESSED</td><td>processed_weather</td><td>2023-06-06T18:58:10.598+0000</td><td>2023-06-06T18:58:20.703+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-06T18:53:59.000+0000</td><td>2023-06-06T18:54:01.000+0000</td><td>2023-06-06T18:58:10.598+0000</td><td>Ashmin Bhattarai</td></tr><tr><td>57cda229-09ce-42c4-8a77-3cb05af044ac</td><td>RAW</td><td>raw_weather</td><td>2023-06-06T18:57:47.633+0000</td><td>2023-06-06T18:58:04.638+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-06T18:54:01.000+0000</td><td>2023-06-06T18:53:59.000+0000</td><td>2023-06-06T18:57:47.633+0000</td><td>Ashmin Bhattarai</td></tr></tbody></table></div>

# %%
# %fs rm -r /user/hive/warehouse/

# %%
# spark.sql('drop table weather_log_table')
